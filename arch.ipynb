# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.linear_model import ElasticNet, LinearRegression
import xgboost as xgb
import matplotlib.pyplot as plt

import openbb as obb
import seaborn as sns
from sklearn.model_selection import train_test_split
from scipy.stats import norm, skewnorm, t

# %%
from arch import arch_model

# %%
output = obb.obb.equity.price.historical("AAPL", start_date="2014-01-01",provider="yfinance")
df = output.to_dataframe()
# Out:
# 1 Failed download:
# ['AAPL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 output = obb.obb.equity.price.historical("AAPL", start_date="2014-01-01",provider="yfinance")
#       2 df = output.to_dataframe()
#
# File ~/Desktop/Financial/Machine-Learning-in-Finance/openbb_env/lib/python3.10/site-packages/openbb_core/app/static/utils/decorators.py:97, in exception_handler.<locals>.wrapper(*f_args, **f_kwargs)
#      93     raise UnauthorizedError(f"\n[Error] -> {e}").with_traceback(
#      94         tb
#      95     ) from None
#      96 if isinstance(e, EmptyDataError):
# ---> 97     raise EmptyDataError(f"\n[Empty] -> {e}").with_traceback(tb) from None
#      98 if isinstance(e, OpenBBError):
#      99     raise OpenBBError(f"\n[Error] -> {e}").with_traceback(tb) from None
#
# File ~/Desktop/Financial/Machine-Learning-in-Finance/openbb_env/lib/python3.10/site-packages/openbb_yfinance/utils/helpers.py:588, in yf_download(symbol, start_date, end_date, interval, period, prepost, actions, progress, ignore_tz, keepna, repair, rounding, group_by, adjusted, **kwargs)
#     585         data = _data
#     587 if data.empty:
# --> 588     raise EmptyDataError()
#     590 data = data.reset_index()
#     591 data = data.rename(columns={"Date": "date", "Datetime": "date"})
#
# EmptyDataError:
# [Empty] -> No results found. Try adjusting the query parameters.

# %%
#Calculating the volatility accurately will give us a good pricing for the options
#and the expected behavior of certain stocks in the future
